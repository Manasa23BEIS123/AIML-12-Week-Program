# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa23BEIS123/AIML-12-Week-Program/blob/feat%2Faiml-W2-Manasa/W2D5_End_to_End_Preprocessing_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# W2D5: End-to-End Preprocessing Pipeline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load Titanic dataset

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

print("Dataset shape:", df.shape)
print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset shape: (891, 12)
#
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# Basic Exploratory Data Analysis (EDA)

print("Dataset Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nBasic Statistics:")
display(df.describe())

print("\nSurvival Distribution:")
print(df["Survived"].value_counts())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# ...

# %%
# Handle missing values

# Fill missing Age values with the median
df["Age"] = df["Age"].fillna(df["Age"].median())

# Fill missing Embarked values with the most frequent value
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# Drop Cabin because it contains many missing values
df = df.drop(columns=["Cabin"])

print("Missing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values after handling:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Encode categorical features

# Label encode Sex
label_encoder = LabelEncoder()
df["Sex"] = label_encoder.fit_transform(df["Sex"])

# One-hot encode Embarked
df = pd.get_dummies(df, columns=["Embarked"], drop_first=True)

print("Dataset after encoding:")
display(df.head())

print("\nData types:")
print(df.dtypes)
# Out:
# Dataset after encoding:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500       False        True
# 1          PC 17599  71.2833       False       False
# 2  STON/O2. 3101282   7.9250       False        True
# ...

# %%
# Select relevant features and target

features = [
    "Pclass",
    "Sex",
    "Age",
    "SibSp",
    "Parch",
    "Fare",
    "Embarked_Q",
    "Embarked_S"
]

X = df[features]
y = df["Survived"]

print("Features shape:", X.shape)
print("Target shape:", y.shape)

display(X.head())
# Out:
# Features shape: (891, 8)
# Target shape: (891,)
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 0       3    1  22.0      1      0   7.2500       False        True
# 1       1    0  38.0      1      0  71.2833       False       False
# 2       3    0  26.0      0      0   7.9250       False        True
# 3       1    0  35.0      1      0  53.1000       False        True
# 4       3    1  35.0      0      0   8.0500       False        True

# %%
# Split features and target into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training set:", X_train.shape)
print("Testing set:", X_test.shape)
# Out:
# Training set: (712, 8)
# Testing set: (179, 8)

# %%
from sklearn.preprocessing import StandardScaler

# Create the scaler
scaler = StandardScaler()

# Fit on training data and transform training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler.transform(X_test)

print("Training data after scaling:")
print(X_train_scaled[:5])

print("\nTest data after scaling:")
print(X_test_scaled[:5])
# Out:
# Training data after scaling:
# [[ 0.82956755  0.74242727 -0.11207776 -0.46508428 -0.46618317  0.5138115
#   -0.28933346  0.61197825]
#  [-0.37094484  0.74242727 -0.11207776 -0.46508428 -0.46618317 -0.66256323
#   -0.28933346  0.61197825]
#  [-1.57145722  0.74242727 -0.11207776 -0.46508428 -0.46618317  3.95539858
#   -0.28933346  0.61197825]
#  [ 0.82956755 -1.34693328 -0.87980748 -0.46508428  0.72778236 -0.46787435
#   -0.28933346  0.61197825]
#  [-0.37094484 -1.34693328  0.11824116  0.47833454  0.72778236 -0.11597681
#   -0.28933346  0.61197825]]
#
# Test data after scaling:
# [[ 0.82956755  0.74242727 -0.41916965  1.42175336 -0.46618317 -0.15970373
#   -0.28933346  0.61197825]
#  [ 0.82956755  0.74242727  1.1162898  -0.46508428  0.72778236 -0.32732356
#   -0.28933346  0.61197825]
#  [ 0.82956755  0.74242727 -0.57271559 -0.46508428 -0.46618317 -0.51212182
#   -0.28933346 -1.63404501]
#  [ 0.82956755  0.74242727  0.88597088  1.42175336 -0.46618317 -0.36879541
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Create the model
model = LogisticRegression(max_iter=1000, random_state=42)

# Train the model
model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.8044692737430168
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       110
#            1       0.79      0.67      0.72        69
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
# Validation checks

assert X_train_scaled.shape[0] == X_train.shape[0]
assert X_test_scaled.shape[0] == X_test.shape[0]

assert X_train_scaled.shape[1] == X_train.shape[1]
assert X_test_scaled.shape[1] == X_test.shape[1]

assert not np.isnan(X_train_scaled).any()
assert not np.isnan(X_test_scaled).any()

print("All validation checks passed!")
print("Training features:", X_train_scaled.shape)
print("Testing features:", X_test_scaled.shape)
# Out:
# All validation checks passed!
# Training features: (712, 8)
# Testing features: (179, 8)

# %%
# Validation checks

assert X_train_scaled.shape[0] == X_train.shape[0]
assert X_test_scaled.shape[0] == X_test.shape[0]

assert X_train_scaled.shape[1] == X_train.shape[1]
assert X_test_scaled.shape[1] == X_test.shape[1]

assert not np.isnan(X_train_scaled).any()
assert not np.isnan(X_test_scaled).any()

print("All validation checks passed!")
print("Training features:", X_train_scaled.shape)
print("Testing features:", X_test_scaled.shape)
# Out:
# All validation checks passed!
# Training features: (712, 8)
# Testing features: (179, 8)

# %%
# Convert scaled arrays back to DataFrames
train_ml_ready = pd.DataFrame(X_train_scaled, columns=features)
test_ml_ready = pd.DataFrame(X_test_scaled, columns=features)

# Add the target column
train_ml_ready["Survived"] = y_train.reset_index(drop=True)
test_ml_ready["Survived"] = y_test.reset_index(drop=True)

# Export to CSV
train_ml_ready.to_csv("titanic_train_ml_ready.csv", index=False)
test_ml_ready.to_csv("titanic_test_ml_ready.csv", index=False)

print("ML-ready datasets exported successfully!")
print("Training file:", train_ml_ready.shape)
print("Testing file:", test_ml_ready.shape)
# Out:
# ML-ready datasets exported successfully!
# Training file: (712, 9)
# Testing file: (179, 9)

# %%
print("Final ML-ready training data:")
display(train_ml_ready.head())

print("\nFinal ML-ready testing data:")
display(test_ml_ready.head())

print("\nMissing values in training data:")
print(train_ml_ready.isnull().sum().sum())

print("\nMissing values in testing data:")
print(test_ml_ready.isnull().sum().sum())
# Out:
# Final ML-ready training data:
#      Pclass       Sex       Age     SibSp     Parch      Fare  Embarked_Q  \
# 0  0.829568  0.742427 -0.112078 -0.465084 -0.466183  0.513812   -0.289333
# 1 -0.370945  0.742427 -0.112078 -0.465084 -0.466183 -0.662563   -0.289333
# 2 -1.571457  0.742427 -0.112078 -0.465084 -0.466183  3.955399   -0.289333
# 3  0.829568 -1.346933 -0.879807 -0.465084  0.727782 -0.467874   -0.289333
# 4 -0.370945 -1.346933  0.118241  0.478335  0.727782 -0.115977   -0.289333
#
#    Embarked_S  Survived
# 0    0.611978         1
# 1    0.611978         0
# 2    0.611978         0
# 3    0.611978         1
# 4    0.611978         1
# Final ML-ready testing data:
#      Pclass       Sex       Age     SibSp     Parch      Fare  Embarked_Q  \
# 0  0.829568  0.742427 -0.419170  1.421753 -0.466183 -0.159704   -0.289333
# 1  0.829568  0.742427  1.116290 -0.465084  0.727782 -0.327324   -0.289333
# 2  0.829568  0.742427 -0.572716 -0.465084 -0.466183 -0.512122   -0.289333
# ...

# %% [markdown]
# ## Conclusion
#
# The Titanic dataset was successfully prepared for machine learning.
#
# - Performed Exploratory Data Analysis (EDA).
# - Handled missing values using median and mode imputation.
# - Encoded categorical features using Label Encoding and One-Hot Encoding.
# - Split the dataset into training and testing sets using an 80/20 split.
# - Applied StandardScaler to the features without data leakage.
# - Trained a Logistic Regression model and evaluated its performance.
# - Validated the preprocessing results.
# - Exported the processed training and testing datasets as ML-ready CSV files.
#
# The final datasets are ready to be used for machine learning tasks.
