# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa23BEIS123/AIML-12-Week-Program/blob/feat%2Faiml-W2-Manasa/W2D4_Train_Test_Split_Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# W2D4: Train/Test Split & Cross-Validation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the Iris dataset

from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target

print("Feature shape:", X.shape)
print("Target shape:", y.shape)
print("Classes:", iris.target_names)
# Out:
# Feature shape: (150, 4)
# Target shape: (150,)
# Classes: ['setosa' 'versicolor' 'virginica']

# %%
# Split data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training features:", X_train.shape)
print("Testing features:", X_test.shape)
print("Training target:", y_train.shape)
print("Testing target:", y_test.shape)
# Out:
# Training features: (120, 4)
# Testing features: (30, 4)
# Training target: (120,)
# Testing target: (30,)

# %%
# Train Logistic Regression model

model = LogisticRegression(max_iter=1000, random_state=42)

model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9666666666666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.90      0.95        10
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
# 5-Fold Cross-Validation

from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    model,
    X,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross-validation scores:")
print(cv_scores)

print("\nMean CV Accuracy:", cv_scores.mean())
print("Standard Deviation:", cv_scores.std())
# Out:
# Cross-validation scores:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
#
# Mean CV Accuracy: 0.9733333333333334
# Standard Deviation: 0.02494438257849294

# %%
# Create 5-fold cross-validation

kf = KFold(n_splits=5, shuffle=True, random_state=42)

fold = 1

for train_index, val_index in kf.split(X):
    print(f"Fold {fold}")
    print("Training samples:", len(train_index))
    print("Validation samples:", len(val_index))
    print("-" * 30)
    fold += 1
# Out:
# Fold 1
# Training samples: 120
# Validation samples: 30
# ------------------------------
# Fold 2
# Training samples: 120
# Validation samples: 30
# ------------------------------
# Fold 3
# Training samples: 120
# Validation samples: 30
# ------------------------------
# Fold 4
# Training samples: 120
# Validation samples: 30
# ------------------------------
# Fold 5
# Training samples: 120
# Validation samples: 30
# ------------------------------

# %%
# Cross-validation summary

print("Cross-Validation Results")
print("-" * 30)

for i, score in enumerate(cv_scores, start=1):
    print(f"Fold {i} Accuracy: {score:.4f}")

print("\nMean Accuracy:", round(cv_scores.mean(), 4))
print("Standard Deviation:", round(cv_scores.std(), 4))
# Out:
# Cross-Validation Results
# ------------------------------
# Fold 1 Accuracy: 0.9667
# Fold 2 Accuracy: 1.0000
# Fold 3 Accuracy: 0.9333
# Fold 4 Accuracy: 0.9667
# Fold 5 Accuracy: 1.0000
#
# Mean Accuracy: 0.9733
# Standard Deviation: 0.0249

# %%
# Final validation checks

assert len(X_train) + len(X_test) == len(X)
assert len(y_train) + len(y_test) == len(y)
assert len(cv_scores) == 5
assert 0 <= cv_scores.mean() <= 1

print("All validation checks passed!")
print("Train/Test Split and Cross-Validation completed successfully.")
# Out:
# All validation checks passed!
# Train/Test Split and Cross-Validation completed successfully.

# %% [markdown]
# ## Conclusion
#
# The dataset was divided into training and testing sets using an 80/20 split.
# Logistic Regression was trained and evaluated on the test data.
# 5-Fold Cross-Validation was performed to measure model performance and consistency across different folds.
